# %%
from datasets import Dataset
import pandas as pd
from pprint import pprint

# %%
role = Dataset.from_json('../../../data/translated/formatted_roleplay_translated.jsonl')
role.shape
# Out:
# Found cached dataset json (/Users/phamhoang1408/.cache/huggingface/datasets/json/default-a16dbd93116385d8/0.0.0)
# (3146, 6)

# %%
temp = role.shuffle()[0]
pprint(temp['instruction_translated'])
pprint(temp['input_translated'])
pprint(temp['output_translated'])
# Out:
# ('Bạn là một nhà báo du hành thời gian được giao nhiệm vụ phỏng vấn Leonardo '
#  'da Vinci. Khi bạn gặp anh ấy trong xưởng của anh ấy, bạn sẽ hỏi anh ấy câu '
#  'hỏi kích thích tư duy nào về quá trình và ý tưởng sáng tạo của anh ấy?')
# ''
# ('Nhạc trưởng Leonardo, những sở thích đa dạng và tài năng đặc biệt của ông '
#  'với tư cách là một nghệ sĩ, nhà khoa học và nhà phát minh đã để lại dấu ấn '
#  'không thể phai mờ trên thế giới. Tôi rất muốn hiểu: làm thế nào để bạn có '
#  'thể kết hợp nhuần nhuyễn thế giới nghệ thuật và khoa học trong công việc của '
#  'mình và điều gì thúc đẩy bạn khám phá nhiều lĩnh vực và ý tưởng như vậy? '
#  'Những hiểu biết của bạn sẽ là vô giá đối với các thế hệ sáng tạo và đổi mới '
#  'trong tương lai.')
